# %% [markdown]
# <a href="https://colab.research.google.com/github/soone0801/20250503/blob/main/Lesson7/lesson7-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.perplexity.ai/search/f834ba4a-c32d-48c7-bfc3-36ef4d2b6d11

# %%
#list
scores:list = [10, 20 , 30, 40, 50]
scores:list = list(range(10,60,10))

# scores1:list = list()
# for score in scores:
#     score += 5
#     scores1.append(score)
scores1 = [score+5 for score in scores]
scores1
# Out:
# [15, 25, 35, 45, 55]

# %%
#numpy
import numpy as np

array = np.array([10, 20 , 30, 40, 50])
type(array)
array1 = array + 5
array1
# Out:
# array([15, 25, 35, 45, 55])

# %%
import numpy as np
from numpy import ndarray

students:ndarray = np.array([[79, 93, 69, 96, 92],
                            [66, 76, 64, 85, 87]])

#利用索引,slicing
students[0] #取得第1位學生資料
students[1] #取得第2位學生資料
students[1,:3] #取得第2位學生資料,前3科分數
students[0,-3:] #取得第1位學生資料,後3科分數
# Out:
# array([69, 96, 92])

# %%
subjects:list[str] = ['chinese', 'english', 'math', 'history', 'discover']
subjects
# Out:
# ['chinese', 'english', 'math', 'history', 'discover']

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot()
axes.plot(subjects, students[0],label="stu1")
axes.plot(subjects,students[1],label="stu2")
axes.legend()
axes.set_title("stu1 vs stu2")
axes.set_xlabel("subject")
axes.set_ylabel('scores')
plt.show()
plt.close()

# %%
figure = plt.figure()
axes1 = figure.add_subplot(1,3,1)
axes2 = figure.add_subplot(1,3,2)
axes3 = figure.add_subplot(1,3,3)
plt.show()
plt.close()
