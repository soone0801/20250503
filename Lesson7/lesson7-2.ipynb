# %% [markdown]
# <a href="https://colab.research.google.com/github/soone0801/20250503/blob/main/Lesson7/lesson7-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.perplexity.ai/search/88657a74-a8c6-49a9-b9cf-0884a64ac45d

# %%
# %pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=ac1507c86e28fd359177b3ee8b304b05dc2508a6fc8c930fa5ad49b9b05e4f71
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
axes.plot(t, y1,marker='*',linestyle='',label="90")
axes.plot(t, y2,marker='s',linestyle='',label="0")
axes.plot(t, y3,marker='^',linestyle='',label="-90")
axes.legend(loc='upper right', bbox_to_anchor=(1.18, 1))
axes.set_title("sin()的正弦波")
axes.set_xlabel("圓周率")
axes.set_ylabel("正弦波值")
plt.show()

# %% [markdown]
# 簡易寫法,使用plt的module
# 如果沒有Figure,幫我建1個Figure
# 如果有Figure,就用這個Figure
# 如果沒有Axes,幫我建1個Axes
# 如果有Axes,就用這個Axes

# %%
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)

plt.plot(t, y1,marker='*',linestyle='',label="90")
plt.plot(t, y2,marker='s',linestyle='',label="0")
plt.plot(t, y3,marker='^',linestyle='',label="-90")
plt.legend(loc='upper right', bbox_to_anchor=(1.18, 1))
plt.title("sin()的正弦波")
plt.xlabel("圓周率")
plt.ylabel("正弦波值")
plt.show()
